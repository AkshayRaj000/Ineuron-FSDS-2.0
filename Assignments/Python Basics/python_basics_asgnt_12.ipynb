# %% [markdown]
# # Python Basics | Assignment 12

# %% [markdown]
# Question Link: https://drive.google.com/file/d/1saNxL1eSkuGhlZ8IXLqXRHZg9AS7YfAS/view

# %% [markdown]
# ### Q.1 | Ans:

# %% [markdown]
# pdf files are binary files so while opening them for reading and writing we should use `rb` and `wb`.

# %%
from PyPDF2 import PdfReader
pdfObj = open('sample_pdf_5pages.pdf', 'rb')
reader = PdfReader(pdfObj)
number_of_pages = len(reader.pages)
page = reader.pages[0]
text = page.extract_text()
print(text)
# Out:
# AutomotiveindustryinIndiaTheautomotiveindustryinIndiaisthefourth-largestbyproductionintheworldasper2022statistics.[1][2][3]Asof2023,Indiaisthe3rdlargestautomobilemarketintheworldintermsofsales.[4]In2022,Indiabecamethefourthlargestcountryintheworldbythevaluationofitsautomotiveindustry.AsofApril2022,India'sautoindustryisworthmorethanUS$100billionandaccountsfor8%ofthecountry'stotalexportsand7.1%ofIndia'sGDP.[5]Accordingtothe2021NationalFamilyHealthSurvey,barely8%ofIndianhouseholdsownanautomobile.[6][7]Accordingtogovernmentstatistics,Indiahasbarely22automobilesper1,000people.[8][9]India'smajorautomobilemanufacturingcompaniesincludesMarutiSuzuki,HyundaiMotorIndia,TataMotors,AshokLeyland,Mahindra&Mahindra,ForceMotors,TractorsandFarmEquipmentLimited,EicherMotors,RoyalEnfield,SonalikaTractors,HindustanMotors,Hradyesh,ICML,KeralaAutomobilesLimited,Reva,PravaigDynamics,Premier,TaraInternationalandVehicleFactoryJabalpur.

# %% [markdown]
# ### Q.2 | Ans :

# %%
page = reader.pages[4]
text = page.extract_text()
print(text)
# Out:
#   Post1992LiberalisationEventuallymultinationalautomakerssuchasSuzukiandToyotaofJapanandHyundaiofSouthKoreawereallowedtoinvestintheIndianmarket,furtheringtheestablishmentofanautomotiveindustryinIndia.MarutiSuzukiwasthefirstandthemostsuccessfulofthesenewentries,inparttheresultofgovernmentpoliciestopromotetheautomotiveindustrybeginninginthe1980s.[14]AsIndiabegantoliberaliseitsautomobilemarketin1991,anumberofforeignfirmsalsoinitiatedjointventureswithexistingIndiancompanies.Thevarietyofoptionsavailabletotheconsumerbegantomultiplyinthenineties,whereasbeforetherehadusuallyonlybeenoneoptionineachpriceclass.By2000,therewere12largeautomotivecompaniesintheIndianmarket,mostofthemoffshootsofglobalcompanies

# %% [markdown]
# ### Q 3 | Ans:

# %%
print(len(reader.pages))
# Out:
# 5

# %% [markdown]
# ### Q 4 | Ans:

# %% [markdown]
# Encryption of PDF:

# %%
from PyPDF2 import PdfReader, PdfWriter

reader = PdfReader("sample_pdf_5pages.pdf")
writer = PdfWriter()

# Add all pages to the writer
for page in reader.pages:
    writer.add_page(page)

# Add a password to the new PDF
writer.encrypt("swordfish")

# Save the new PDF to a file
with open("encrypted-pdf.pdf", "wb") as f:
    writer.write(f)

# %%
from PyPDF2 import PdfReader
pdfObj = open('encrypted-pdf.pdf', 'rb')
reader = PdfReader(pdfObj)
print(reader.is_encrypted) #returns True if our file is encrypted...
number_of_pages = len(reader.pages)
page = reader.pages[0]
text = page.extract_text()
print(text)
# Out:
# True
# ---------------------------------------------------------------------------
# PdfReadError                              Traceback (most recent call last)
# c:\Users\91892\Desktop\iNeuron FSDS - 2.0\Assignments\Python Basics\PBA12_PyPDF2.ipynb Cell 13 line <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/91892/Desktop/iNeuron%20FSDS%20-%202.0/Assignments/Python%20Basics/PBA12_PyPDF2.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> reader = PdfReader(pdfObj)
#       <a href='vscode-notebook-cell:/c%3A/Users/91892/Desktop/iNeuron%20FSDS%20-%202.0/Assignments/Python%20Basics/PBA12_PyPDF2.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> print(reader.is_encrypted) #returns True if our file is encrypted...
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91892/Desktop/iNeuron%20FSDS%20-%202.0/Assignments/Python%20Basics/PBA12_PyPDF2.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> number_of_pages = len(reader.pages)
#       <a href='vscode-notebook-cell:/c%3A/Users/91892/Desktop/iNeuron%20FSDS%20-%202.0/Assignments/Python%20Basics/PBA12_PyPDF2.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a> page = reader.pages[0]
#       <a href='vscode-notebook-cell:/c%3A/Users/91892/Desktop/iNeuron%20FSDS%20-%202.0/Assignments/Python%20Basics/PBA12_PyPDF2.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> text = page.extract_text()
#
# File c:\Users\91892\anaconda3\lib\site-packages\PyPDF2\_page.py:1482, in _VirtualList.__len__(self)
#    1481 def __len__(self) -> int:
# -> 1482     return self.length_function()
#
# File c:\Users\91892\anaconda3\lib\site-packages\PyPDF2\_reader.py:389, in PdfReader._get_num_pages(self)
#     385 # Flattened pages will not work on an Encrypted PDF;
#     386 # the PDF file's page count is used in this case. Otherwise,
#     387 # the original method (flattened page count) is used.
#     388 if self.is_encrypted:
# --> 389     return self.trailer[TK.ROOT]["/Pages"]["/Count"]  # type: ignore
#     390 else:
#     391     if self.flattened_pages is None:
#
# File c:\Users\91892\anaconda3\lib\site-packages\PyPDF2\generic.py:680, in DictionaryObject.__getitem__(self, key)
#     679 def __getitem__(self, key: Any) -> PdfObject:
# --> 680     return dict.__getitem__(self, key).get_object()
#
# File c:\Users\91892\anaconda3\lib\site-packages\PyPDF2\generic.py:252, in IndirectObject.get_object(self)
#     251 def get_object(self) -> Optional[PdfObject]:
# --> 252     obj = self.pdf.get_object(self)
#     253     if obj is None:
#     254         return None
#
# File c:\Users\91892\anaconda3\lib\site-packages\PyPDF2\_reader.py:1090, in PdfReader.get_object(self, indirect_reference)
#    1087 if not self._override_encryption and self._encryption is not None:
#    1088     # if we don't have the encryption key:
#    1089     if not self._encryption.is_decrypted():
# -> 1090         raise PdfReadError("File has not been decrypted")
#    1091     # otherwise, decrypt here...
#    1092     retval = cast(PdfObject, retval)
#
# PdfReadError: File has not been decrypted

# %% [markdown]
# We have encrypted our file and saved it in directory.
#
# Now if we want to create page object from our encrypted file, we need to first decrypt the file.

# %% [markdown]
# Decrypting file:

# %%
from PyPDF2 import PdfReader, PdfWriter

reader = PdfReader("encrypted-pdf.pdf")
writer = PdfWriter()

if reader.is_encrypted:
    reader.decrypt("swordfish")

# Add all pages to the writer
for page in reader.pages:
    writer.add_page(page)

# Save the new PDF to a file
with open("decrypted-pdf.pdf", "wb") as f:
    writer.write(f)

# %%
# After decryption now we can read data from the file.
from PyPDF2 import PdfReader
pdfObj = open('decrypted-pdf.pdf', 'rb')
reader = PdfReader(pdfObj)
print(reader.is_encrypted) #returns True if our file is encrypted...
number_of_pages = len(reader.pages)
page = reader.pages[0]
text = page.extract_text()
print(text)
# Out:
# False
# AutomotiveindustryinIndiaTheautomotiveindustryinIndiaisthefourth-largestbyproductionintheworldasper2022statistics.[1][2][3]Asof2023,Indiaisthe3rdlargestautomobilemarketintheworldintermsofsales.[4]In2022,Indiabecamethefourthlargestcountryintheworldbythevaluationofitsautomotiveindustry.AsofApril2022,India'sautoindustryisworthmorethanUS$100billionandaccountsfor8%ofthecountry'stotalexportsand7.1%ofIndia'sGDP.[5]Accordingtothe2021NationalFamilyHealthSurvey,barely8%ofIndianhouseholdsownanautomobile.[6][7]Accordingtogovernmentstatistics,Indiahasbarely22automobilesper1,000people.[8][9]India'smajorautomobilemanufacturingcompaniesincludesMarutiSuzuki,HyundaiMotorIndia,TataMotors,AshokLeyland,Mahindra&Mahindra,ForceMotors,TractorsandFarmEquipmentLimited,EicherMotors,RoyalEnfield,SonalikaTractors,HindustanMotors,Hradyesh,ICML,KeralaAutomobilesLimited,Reva,PravaigDynamics,Premier,TaraInternationalandVehicleFactoryJabalpur.

# %% [markdown]
# ### Q 5 | Ans:

# %%
from PyPDF2 import PdfWriter, PdfReader

reader = PdfReader("sample_pdf_5pages.pdf")
writer = PdfWriter()


writer.add_page(reader.pages[0])
writer.pages[0].rotate(90)

with open("sample_rotated.pdf", "wb") as fp:
    writer.write(fp)

# %% [markdown]
# after rotation:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q 6 | Ans:

# %% [markdown]
# In simple terms, a paragraph is a block of text in Microsoft Word, while a run is a portion of text within a paragraph that has a specific format.

# %% [markdown]
# A Run object is a contiguous sequence of characters that all have the same set of formatting properties. For example, a run can contain a word or a group of words that have the same font, size, color, and other formatting properties. Runs can be accessed within a paragraph object, and a paragraph can contain one or more runs.
# A Paragraph object, on the other hand, represents a single paragraph in a document. It consists of one or more runs, and it contains information about the paragraph's formatting properties, such as indentation, alignment, and line spacing.
# The main difference between a Run and a Paragraph object is that a Run represents a continuous sequence of characters with the same formatting, while a Paragraph represents a block of text with its own set of formatting properties.

# %% [markdown]
# ### Q 7 | Ans

# %%
import docx
doc = docx.Document('Auto.docx')
# doc.paragraphs
for i in doc.paragraphs:
    text = doc.paragraphs

# %% [markdown]
# ### Q 8 | Ans:

# %% [markdown]
# `extract_text()` method have underline,italic,strike and outline variables

# %% [markdown]
# ### Q 9 | Ans:

# %% [markdown]
# In PyPDF2, the bold attribute of a TextObject object can take three different values: True, False, or None. Here's what each of these values means:
#
# True: The text is bold.
#
# False: The text is not bold.
#
# None: The text's boldness is unknown or undefined.

# %% [markdown]
# ### Q 10 | Ans:

# %% [markdown]
# By Calling the `docx.Document()` function.

# %% [markdown]
# ### Q 11 | Ans

# %%
import docx
doc = docx.Document()

doc.add_paragraph('Hello there!')
doc.save('hellothere.docx')

# %% [markdown]
# ### Q 12 | Ans:

# %% [markdown]
# integer from 0 to 4,
# The arguments to add_heading() are a string of the heading text and an integer from 0 to 4. The integer 0 makes the heading the Title style, which is used for the top of the document. Integers 1 to 4 are for various heading levels, with 1 being the main heading and 4 the lowest subheading
